# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.Name
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df[['Name','HP']]
# Out:
#                       Name  HP
# 0                Bulbasaur  45
# 1                  Ivysaur  60
# 2                 Venusaur  80
# 3    VenusaurMega Venusaur  80
# 4               Charmander  39
# ..                     ...  ..
# 795                Diancie  50
# 796    DiancieMega Diancie  50
# 797    HoopaHoopa Confined  80
# 798     HoopaHoopa Unbound  80
# 799              Volcanion  80
#
# [800 rows x 2 columns]

# %%
df.loc[50:75,['Name','Attack','HP']]
# df.iloc[50:75,[1,3,5]]
# Out:
#                      Name  Attack  HP
# 50              Vileplume      80  75
# 51                  Paras      70  35
# 52               Parasect      95  60
# 53                Venonat      55  60
# 54               Venomoth      65  70
# 55                Diglett      55  10
# 56                Dugtrio      80  35
# 57                 Meowth      45  40
# 58                Persian      70  65
# 59                Psyduck      52  50
# 60                Golduck      82  80
# 61                 Mankey      80  40
# 62               Primeape     105  65
# 63              Growlithe      70  55
# 64               Arcanine     110  90
# 65                Poliwag      50  40
# 66              Poliwhirl      65  65
# 67              Poliwrath      95  90
# 68                   Abra      20  25
# 69                Kadabra      35  40
# 70               Alakazam      50  55
# 71  AlakazamMega Alakazam      50  55
# 72                 Machop      80  70
# 73                Machoke     100  80
# ...

# %%
df[['Name','HP']].head(10)
# Out:
#                         Name  HP
# 0                  Bulbasaur  45
# 1                    Ivysaur  60
# 2                   Venusaur  80
# 3      VenusaurMega Venusaur  80
# 4                 Charmander  39
# 5                 Charmeleon  58
# 6                  Charizard  78
# 7  CharizardMega Charizard X  78
# 8  CharizardMega Charizard Y  78
# 9                   Squirtle  44

# %%
df = pd.read_csv('/content/students.csv')

# %%
df
# Out:
#     Enrollment_No                   Name  Python_marks  Java_marks  SE_marks
# 0               1               John Doe            85          78      90.0
# 1               2             Jane Smith            92          88      85.0
# 2               3          Alice Johnson            78          85      92.0
# 3               4           Bob Williams            92          78       NaN
# 4               5            Emily Brown            85          78      90.0
# 5               6          Michael Davis            92          88      85.0
# 6               7           Sarah Miller            78          85      92.0
# 7               8           David Wilson            90          92      78.0
# 8               9            Emma Taylor            85          78      90.0
# 9              10         James Anderson            92          85       NaN
# 10             11        Olivia Martinez            78          85      92.0
# ...

# %%
df
# Out:
#     Enrollment_No                   Name  Python_marks  Java_marks  SE_marks
# 0               1               John Doe            85          78      90.0
# 1               2             Jane Smith            92          88      85.0
# 2               3          Alice Johnson            78          85      92.0
# 3               4           Bob Williams            92          78       NaN
# 4               5            Emily Brown            85          78      90.0
# 5               6          Michael Davis            92          88      85.0
# 6               7           Sarah Miller            78          85      92.0
# 7               8           David Wilson            90          92      78.0
# 8               9            Emma Taylor            85          78      90.0
# 9              10         James Anderson            92          85       NaN
# 10             11        Olivia Martinez            78          85      92.0
# ...

# %%
dr = df.duplicated(subset=['Name','Python_marks'])
print(dr)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# dtype: bool

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#     Enrollment_No                   Name  Python_marks  Java_marks  SE_marks
# 0               1               John Doe            85          78      90.0
# 1               2             Jane Smith            92          88      85.0
# 2               3          Alice Johnson            78          85      92.0
# 3               4           Bob Williams            92          78       NaN
# 4               5            Emily Brown            85          78      90.0
# 5               6          Michael Davis            92          88      85.0
# 6               7           Sarah Miller            78          85      92.0
# 7               8           David Wilson            90          92      78.0
# 8               9            Emma Taylor            85          78      90.0
# 9              10         James Anderson            92          85       NaN
# 10             11        Olivia Martinez            78          85      92.0
# ...

# %%
df = pd.read_csv('/content/students.csv')
df
# Out:
#     Enrollment_No                   Name  Python_marks  Java_marks  SE_marks
# 0               1        Jaimin Radadiay            85          78      90.0
# 1               2             Jane Smith            92          88      85.0
# 2               3          Alice Johnson            78          85      92.0
# 3               4           Bob Williams            92          78       NaN
# 4               5            Emily Brown            85          78      90.0
# 5               6          Michael Davis            92          88      85.0
# 6               7           Sarah Miller            78          85      92.0
# 7               8           David Wilson            90          92      78.0
# 8               9          Michael Davis            92          88       NaN
# 9              10         James Anderson            92          85       NaN
# 10             11        Olivia Martinez            78          85      92.0
# ...

# %%
dr = df.duplicated(subset=['Name','Python_marks'])
print(dr)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# dtype: bool

# %%
dup = df[df.duplicated(subset=['Name'])]
dup
# Out:
#     Enrollment_No           Name  Python_marks  Java_marks  SE_marks
# 8               9  Michael Davis            92          88       NaN
# 15             16  William Clark            90          92      78.0
# 19             20      Ava Young            85          78      90.0

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of     Enrollment_No                   Name  Python_marks  Java_marks  SE_marks
# 0               1        Jaimin Radadiay            85          78      90.0
# 1               2             Jane Smith            92          88      85.0
# 2               3          Alice Johnson            78          85      92.0
# 3               4           Bob Williams            92          78       NaN
# 4               5            Emily Brown            85          78      90.0
# 5               6          Michael Davis            92          88      85.0
# 6               7           Sarah Miller            78          85      92.0
# 7               8           David Wilson            90          92      78.0
# 8               9          Michael Davis            92          88       NaN
# 9              10         James Anderson            92          85       NaN
# 10             11        Olivia Martinez            78          85      92.0
# ...

# %%
df.isna()
# Out:
#     Enrollment_No   Name  Python_marks  Java_marks  SE_marks
# 0           False  False         False       False     False
# 1           False  False         False       False     False
# 2           False  False         False       False     False
# 3           False  False         False       False      True
# 4           False  False         False       False     False
# 5           False  False         False       False     False
# 6           False  False         False       False     False
# 7           False  False         False       False     False
# 8           False  False         False       False      True
# 9           False  False         False       False      True
# 10          False  False         False       False     False
# 11          False  False         False       False     False
# 12          False  False         False       False     False
# 13          False  False         False       False      True
# ...

# %%
df.head(5)
# Out:
#    Enrollment_No             Name  Python_marks  Java_marks  SE_marks
# 0              1  Jaimin Radadiay            85          78      90.0
# 1              2       Jane Smith            92          88      85.0
# 2              3    Alice Johnson            78          85      92.0
# 3              4     Bob Williams            92          78       NaN
# 4              5      Emily Brown            85          78      90.0

# %%
df.tail(7)
# Out:
#     Enrollment_No                   Name  Python_marks  Java_marks  SE_marks
# 13             14          Matthew Lewis            92          85       NaN
# 14             15           Chloe Walker            78          85      92.0
# 15             16          William Clark            90          92      78.0
# 16             17              Ava Young            85          78      90.0
# 17             18  Christopher Hernandez            92          88      85.0
# 18             19          Samantha King            78          85      92.0
# 19             20              Ava Young            85          78      90.0

# %%
df['Java_marks'].max()
# Out:
# 92

# %%
df['Python_marks'].min()
# Out:
# 78

# %%
df.iloc[df['Python_marks'].idxmax()]
# Out:
# Enrollment_No             2
# Name             Jane Smith
# Python_marks             92
# Java_marks               88
# SE_marks               85.0
# Name: 1, dtype: object

# %%
df[['Python_marks','Java_marks','SE_marks']].mean()
# Out:
# Python_marks    86.4500
# Java_marks      84.5500
# SE_marks        87.4375
# dtype: float64

# %%
df = df.assign(Total = df['Python_marks'] + df['Java_marks'] + df['SE_marks'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-00c944d080d4> in <cell line: 1>()
# ----> 1 df = df.assign(Total = df['Python_marks'] + df['Java_marks'] + df['SE_marks'])
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/car_sales.csv')
df
# Out:
#           Date      Salesperson          Customer Name   Car Make  Car Model  \
# 0   2022-08-01  Monica Moore MD            Mary Butler     Nissan     Altima
# 1   2023-03-15     Roberto Rose         Richard Pierce     Nissan      F-150
# 2   2023-04-29     Ashley Ramos           Sandra Moore       Ford      Civic
# 3   2022-09-04   Patrick Harris           Johnny Scott       Ford     Altima
# 4   2022-06-16       Eric Lopez          Vanessa Jones      Honda  Silverado
# ..         ...              ...                    ...        ...        ...
# 94  2023-01-23    Donald Guerra           John Goodwin       Ford     Altima
# 95  2023-03-13      Alyssa Boyd           James Turner     Nissan      F-150
# 96  2022-12-31      Ryan Barnes              Mary Wong     Toyota  Silverado
# 97  2022-12-29     Megan Kaiser  Christopher Alexander       Ford      Civic
# 98  2023-04-16   Michael Jordan     Thomas Blankenship  Chevrolet     Altima
#
# ...

# %%
df['Car Make'].value_counts()
# Out:
# Ford         23
# Chevrolet    22
# Nissan       20
# Honda        17
# Toyota       17
# Name: Car Make, dtype: int64

# %%
df['Car Year'].value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-b6f5c0c383b6> in <cell line: 1>()
# ----> 1 df['Car Year'].value_count()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
unique_car_makes = df['Car Make'].unique()
unique_car_models = df['Car Model'].unique()

# %%
print("Uniqu Car Marks :\n ", unique_car_makes)
print("Uniqu Car Marks :\n ", unique_car_models)
# Out:
# Uniqu Car Marks :
#   ['Nissan' 'Ford' 'Honda' 'Toyota' 'Chevrolet']
# Uniqu Car Marks :
#   ['Altima' 'F-150' 'Civic' 'Silverado' 'Corolla']

# %%
import matplotlib.pyplot as plt

# %%
car_make_counts = df['Car Model'].value_counts()
fig, ax = plt.subplots(figsize=(8,8))
ax.pie(car_make_counts, labels=car_make_counts.index, autopct='%1.5f%%', startangle=90)
ax.axis('Equal')
ax.set_title("Distrabution of Car Model")

plt.show()

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15,30,45,10]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dd24b709f1c8> in <cell line: 4>()
#       2 sizes = [15,30,45,10]
#       3
# ----> 4 fig, ax = plt.subplots()
#       5 ax.pie(sizes, labels=labels, autopct='%1.1f%%')
#       6 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df
# Out:
#           Date      Salesperson          Customer Name   Car Make  Car Model  \
# 0   2022-08-01  Monica Moore MD            Mary Butler     Nissan     Altima
# 1   2023-03-15     Roberto Rose         Richard Pierce     Nissan      F-150
# 2   2023-04-29     Ashley Ramos           Sandra Moore       Ford      Civic
# 3   2022-09-04   Patrick Harris           Johnny Scott       Ford     Altima
# 4   2022-06-16       Eric Lopez          Vanessa Jones      Honda  Silverado
# ..         ...              ...                    ...        ...        ...
# 94  2023-01-23    Donald Guerra           John Goodwin       Ford     Altima
# 95  2023-03-13      Alyssa Boyd           James Turner     Nissan      F-150
# 96  2022-12-31      Ryan Barnes              Mary Wong     Toyota  Silverado
# 97  2022-12-29     Megan Kaiser  Christopher Alexander       Ford      Civic
# 98  2023-04-16   Michael Jordan     Thomas Blankenship  Chevrolet     Altima
#
# ...

# %%
top_salespersons = df['Salesperson'].value_counts()
print(top_salespersons)
# Out:
# Monica Moore MD       1
# Kimberly Rasmussen    1
# Hayley Day            1
# Charles Cruz          1
# Laura Huff            1
#                      ..
# Brenda Morales        1
# Jason Cabrera         1
# Paul Potter           1
# Amber Cooper          1
# Michael Jordan        1
# Name: Salesperson, Length: 99, dtype: int64

# %%
df['Commission Earned'].idxmax()
# Out:
# 55

# %%
df.iloc[df['Commission Earned'].idxmax()]
# Out:
# Date                   2023-02-11
# Salesperson           David Gomez
# Customer Name        Linda Conrad
# Car Make                   Nissan
# Car Model                  Altima
# Car Year                     2019
# Sale Price                  46164
# Commission Rate          0.144674
# Commission Earned         6678.72
# Name: 55, dtype: object

# %%
df.iloc[df['Commission Earned'].idxmin()]
# Out:
# Date                     2022-12-30
# Salesperson          Shawn Cummings
# Customer Name         Kelly Beasley
# Car Make                  Chevrolet
# Car Model                    Altima
# Car Year                       2013
# Sale Price                    15064
# Commission Rate            0.053382
# Commission Earned            804.14
# Name: 33, dtype: object

# %%
data = df.iloc[df['Commission Earned'].idxmax()]
data['Customer Name']
# Out:
# 'Linda Conrad'

# %%
data = df.iloc[df['Commission Earned'].idxmax()]
type(data)
# Out:
# pandas.core.series.Series

# %%
data = df.iloc[df['Commission Earned'].idxmax()]
data
# Out:
# Date                   2023-02-11
# Salesperson           David Gomez
# Customer Name        Linda Conrad
# Car Make                   Nissan
# Car Model                  Altima
# Car Year                     2019
# Sale Price                  46164
# Commission Rate          0.144674
# Commission Earned         6678.72
# Name: 55, dtype: object

# %%
data = df.iloc[df['Commission Earned'].idxmin()]
data
# Out:
# Date                     2022-12-30
# Salesperson          Shawn Cummings
# Customer Name         Kelly Beasley
# Car Make                  Chevrolet
# Car Model                    Altima
# Car Year                       2013
# Sale Price                    15064
# Commission Rate            0.053382
# Commission Earned            804.14
# Name: 33, dtype: object

# %%
df
# Out:
#           Date      Salesperson          Customer Name   Car Make  Car Model  \
# 0   2022-08-01  Monica Moore MD            Mary Butler     Nissan     Altima
# 1   2023-03-15     Roberto Rose         Richard Pierce     Nissan      F-150
# 2   2023-04-29     Ashley Ramos           Sandra Moore       Ford      Civic
# 3   2022-09-04   Patrick Harris           Johnny Scott       Ford     Altima
# 4   2022-06-16       Eric Lopez          Vanessa Jones      Honda  Silverado
# ..         ...              ...                    ...        ...        ...
# 94  2023-01-23    Donald Guerra           John Goodwin       Ford     Altima
# 95  2023-03-13      Alyssa Boyd           James Turner     Nissan      F-150
# 96  2022-12-31      Ryan Barnes              Mary Wong     Toyota  Silverado
# 97  2022-12-29     Megan Kaiser  Christopher Alexander       Ford      Civic
# 98  2023-04-16   Michael Jordan     Thomas Blankenship  Chevrolet     Altima
#
# ...

# %%
car_make_counts = df['Sale Price'].value_counts()
fig, ax = plt.subplots(figsize=(10,10))
ax.pie(car_make_counts, labels=car_make_counts.index, autopct='%1.5f%%', startangle=90)
ax.axis('Equal')
ax.set_title("Distrabution of CSale Price	")

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df['Car Make'].value_counts().idxmax()
# Out:
# 'Ford'

# %%
data = df['Car Make'].value_counts().idxmin()
data
# Out:
# 'Honda'

# %%
data = df['Car Make'].value_counts().tail(2)
data
# Out:
# Honda     17
# Toyota    17
# Name: Car Make, dtype: int64

# %%
# Group by
yearly_sals = df.groupby('Car Year')
yearly_sals.get_group(2018)
# Out:
#           Date      Salesperson      Customer Name Car Make  Car Model  \
# 0   2022-08-01  Monica Moore MD        Mary Butler   Nissan     Altima
# 9   2023-04-06     Andrew Smith  Ashley Moreno DDS     Ford      Civic
# 17  2022-08-23      Amy Solomon       Taylor Moore   Nissan  Silverado
# 27  2022-07-14     Amber Cooper         Claire Day   Nissan      F-150
# 28  2022-07-17      Paul Potter         Corey West    Honda    Corolla
# 37  2023-01-24    Julie Aguirre      Timothy Mccoy   Nissan  Silverado
# 75  2023-02-19     Shawn Mullen       Jeremy Jones   Nissan      Civic
# 88  2023-03-16   Kenneth Fields       Audrey Gomez    Honda      Civic
# 96  2022-12-31      Ryan Barnes          Mary Wong   Toyota  Silverado
#
#     Car Year  Sale Price  Commission Rate  Commission Earned
# 0       2018       15983         0.070495            1126.73
# 9       2018       16309         0.149926            2445.14
# 17      2018       18482         0.086185            1592.88
# ...

# %%
# Group by
# sort values and sum
yearly_sals = df.groupby('Car Year')['Sale Price'].sum().reset_index()
# yearly_sals = yearly_sals.sort_values(by='Sale Price', ascending=True)
print(yearly_sals)
# Out:
#     Car Year  Sale Price
# 0       2010      142580
# 1       2011      150129
# 2       2012      210482
# 3       2013      295947
# 4       2014      201012
# 5       2015      304547
# 6       2016      423997
# 7       2017      113807
# 8       2018      209907
# 9       2019      206686
# 10      2020       75674
# 11      2021      145032
# 12      2022      353876

# %% [markdown]
# Is there a relationship between car make and salse price

# %%
plt.scatter(df['Car Make'],[df['Sale Price']])
plt.xlabel('Car Make')
plt.ylabel('Sale Price')
plt.show()

# %%
model_commission = df.groupby('Car Model')['Commission Earned'].mean()
print(model_commission)
# Out:
# Car Model
# Altima       2819.594231
# Civic        3163.737500
# Corolla      2734.687500
# F-150        3214.408750
# Silverado    3086.466923
# Name: Commission Earned, dtype: float64

# %%
salesperson_sales = df.groupby('Salesperson')['Sale Price'].sum()
salesperson_commission = df.groupby('Salesperson')['Commission Earned'].sum()

salesperson_sales = salesperson_sales.sort_values(ascending=False)

# sort by commission earned

salesperson_commission = salesperson_commission.sort_values(ascending=False)
salesperson_commission

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
