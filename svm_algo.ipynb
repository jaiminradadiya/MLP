# %%
# pandas
import pandas as pd

# %%
data =  pd.read_csv("TeamsHalf.csv")
data.head()
# Out:
#    year lgID tmID  half  rank   G  W  L  T  GF  GA
# 0  1916  NHA  MOC     1     1  10  7  3  0  58  38
# 1  1916  NHA  MOC     2     3  10  3  7  0  31  42
# 2  1916  NHA  MOW     1     5  10  3  7  0  56  72
# 3  1916  NHA  MOW     2     4  10  2  8  0  38  65
# 4  1916  NHA  OT1     1     2  10  7  3  0  56  41

# %%
sliced_x = data.iloc[:,0:3].join(data.iloc[:,4:8])
sliced_x.head()
# Out:
#    year lgID tmID  rank   G  W  L
# 0  1916  NHA  MOC     1  10  7  3
# 1  1916  NHA  MOC     3  10  3  7
# 2  1916  NHA  MOW     5  10  3  7
# 3  1916  NHA  MOW     4  10  2  8
# 4  1916  NHA  OT1     2  10  7  3

# %%
from sklearn.preprocessing import LabelEncoder
toBeEncode = ['year', 'lgID','tmID', 'rank', 'G','L']
encoder = LabelEncoder()
for col in toBeEncode:
    sliced_x[col]= encoder.fit_transform(sliced_x[col])

# %%
sliced_y = data.iloc[:,3:4].values
# sliced_y.head()
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y = train_test_split(sliced_x,sliced_y,test_size=0.3)

# %%
# svm
from sklearn import svm
classifier = svm.SVC(kernel='linear')
classifier.fit(train_x,train_y)
# Out:
# C:\Users\bhavd\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='linear')

# %%
# predict 
result = classifier.predict(test_x)
print(f"Result : {result}")
# Out:
# Result : [2 2 1 1 2 2 1 1 1 2 1 1 2]

# %%
# accuracy
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(result,test_y)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.38461538461538464

# %%
# Precison
from sklearn.metrics import precision_score
precision = precision_score(result,test_y,average='weighted')
print(f"Precision: {precision}")
# Out:
# Precision: 0.38461538461538464

# %%
# Recall
from sklearn.metrics import recall_score
recall = recall_score(result,test_y,average='weighted')
print(f"Recall: {recall}")
# Out:
# Recall: 0.38461538461538464

# %%
# F1
from sklearn.metrics import f1_score
f1 = f1_score(result,test_y,average='weighted')
print(f"F1: {f1}")
# Out:
# F1: 0.38461538461538464
